# %%
import requests
import random
from datetime import timedelta, datetime
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
Cryptokey = '281fa191-6714-4dc8-933a-8ff13fca4ab8'

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
    'start': '1',
    'limit': '5000',
    'convert': 'USD'
}
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': Cryptokey,
}

# %%
session = requests.Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
#     print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %%
data['data']
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 8362,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channels',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'galaxy-digital-portfolio',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-xzy-screener'],
#   'max_supply': 21000000,
#   'circulating_supply': 18844675,
#   'total_supply': 18844675,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2021-10-15T20:01:02.000Z',
#   'quote': {'USD': {'price': 61386.793987090685,
#     'volume_24h': 46905176688.78917,
#     'volume_change_24h': 19.584,
#     'percent_change_1h': -0.39226551,
#     'percent_change_24h': 6.18543687,
#     'percent_change_7d': 12.26256179,
#     'percent_change_30d': 27.58709068,
#     'percent_change_60d': 33.1838315,
#     'percent_change_90d': 92.62128028,
#     'market_cap': 1156814181978.6782,
#     'market_cap_dominance': 46.5873,
#     'fully_diluted_market_cap': 1289122673728.9,
#     'last_updated': '2021-10-15T20:01:02.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 4921,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'smart-contracts',
#    'ethereum',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'hashkey-capital-portfolio',
#    'kinetic-capital',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-xzy-screener'],
#   'max_supply': None,
#   'circulating_supply': 117939650.374,
#   'total_supply': 117939650.374,
#   'platform': None,
#   'cmc_rank': 2,
#   'last_updated': '2021-10-15T20:01:02.000Z',
#   'quote': {'USD': {'price': 3846.0564948488122,
#     'volume_24h': 19770820890.450027,
#     'volume_change_24h': -3.1299,
#     'percent_change_1h': -0.89998031,
#     'percent_change_24h': 1.47545437,
#     'percent_change_7d': 6.05285737,
#     'percent_change_30d': 8.61527509,
#     'percent_change_60d': 21.34542794,
#     'percent_change_90d': 101.20940416,
#     'market_cap': 453602558321.12085,
#     'market_cap_dominance': 18.2675,
#     'fully_diluted_market_cap': 453602558321.12,
#     'last_updated': '2021-10-15T20:01:02.000Z'}}},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'slug': 'binance-coin',
#   'num_market_pairs': 538,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'payments',
#    'binance-smart-chain',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio'],
#   'max_supply': 168137036,
#   'circulating_supply': 168137036,
#   'total_supply': 168137036,
#   'platform': None,
#   'cmc_rank': 3,
#   'last_updated': '2021-10-15T20:00:11.000Z',
#   'quote': {'USD': {'price': 474.4636489920417,
#     'volume_24h': 2723299289.1640267,
#     'volume_change_24h': -0.4398,
#     'percent_change_1h': -0.08322236,
#     'percent_change_24h': 1.07635483,
#     'percent_change_7d': 12.06272585,
#     'percent_change_30d': 10.4067816,
#     'percent_change_60d': 12.92755672,
#     'percent_change_90d': 56.09652257,
#     'market_cap': 79774911631.26628,
#     'market_cap_dominance': 3.2127,
#     'fully_diluted_market_cap': 79774911631.27,
#     'last_updated': '2021-10-15T20:00:11.000Z'}}},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 306,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['mineable',
#    'dpos',
#    'pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'staking',
#    'binance-smart-chain'],
#   'max_supply': 45000000000,
#   'circulating_supply': 32904527668.666,
#   'total_supply': 33250650235.236,
#   'platform': None,
#   'cmc_rank': 4,
#   'last_updated': '2021-10-15T20:00:17.000Z',
#   'quote': {'USD': {'price': 2.21736664566005,
#     'volume_24h': 3240880311.5531673,
#     'volume_change_24h': 40.6767,
#     'percent_change_1h': -0.24033931,
#     'percent_change_24h': 1.57564244,
#     'percent_change_7d': -2.22097817,
#     'percent_change_30d': -12.21849431,
#     'percent_change_60d': 5.30261685,
#     'percent_change_90d': 85.76172412,
#     'market_cap': 72961402143.69824,
#     'market_cap_dominance': 2.9383,
#     'fully_diluted_market_cap': 99781499054.7,
#     'last_updated': '2021-10-15T20:00:17.000Z'}}},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 18893,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': ['payments',
#    'stablecoin',
#    'stablecoin-asset-backed',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'solana-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 68589070064.13161,
#   'total_supply': 71385677464.76012,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'cmc_rank': 5,
#   'last_updated': '2021-10-15T20:00:12.000Z',
#   'quote': {'USD': {'price': 0.99920059941277,
#     'volume_24h': 84190099950.04808,
#     'volume_change_24h': 16.2827,
#     'percent_change_1h': -0.04583278,
#     'percent_change_24h': -0.08561381,
#     'percent_change_7d': -0.10841642,
#     'percent_change_30d': -0.13343004,
#     'percent_change_60d': -0.12048604,
#     'percent_change_90d': -0.10152387,
#     'market_cap': 68534239921.244774,
#     'market_cap_dominance': 2.76,
#     'fully_diluted_market_cap': 71328611712.28,
#     'last_updated': '2021-10-15T20:00:12.000Z'}}},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 637,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'binance-chain',
#    'arrington-xrp-capital',
#    'galaxy-digital-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio'],
#   'max_supply': 100000000000,
#   'circulating_supply': 46878114887,
#   'total_supply': 99990202996,
#   'platform': None,
#   'cmc_rank': 6,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 1.14556383543237,
#     'volume_24h': 5112116926.646347,
#     'volume_change_24h': 56.4235,
#     'percent_change_1h': -0.27941082,
#     'percent_change_24h': 1.23209597,
#     'percent_change_7d': 6.58314375,
#     'percent_change_30d': 1.93213865,
#     'percent_change_60d': -5.7774313,
#     'percent_change_90d': 92.59555962,
#     'market_cap': 53701873087.79101,
#     'market_cap_dominance': 2.1627,
#     'fully_diluted_market_cap': 114556383543.24,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 5426,
#   'name': 'Solana',
#   'symbol': 'SOL',
#   'slug': 'solana',
#   'num_market_pairs': 163,
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'solana-ecosystem',
#    'cms-holdings-portfolio',
#    'kinetic-capital',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 300272998.531346,
#   'total_supply': 506552641.13335127,
#   'platform': None,
#   'cmc_rank': 7,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 160.3458867626934,
#     'volume_24h': 3632932285.1963005,
#     'volume_change_24h': 74.0953,
#     'percent_change_1h': -0.35641564,
#     'percent_change_24h': 7.03445376,
#     'percent_change_7d': -1.52305995,
#     'percent_change_30d': -0.68990962,
#     'percent_change_60d': 154.77272002,
#     'percent_change_90d': 488.29020183,
#     'market_cap': 48147540220.40161,
#     'market_cap_dominance': 1.939,
#     'fully_diluted_market_cap': 81223632434.51,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'slug': 'polkadot-new',
#   'num_market_pairs': 247,
#   'date_added': '2020-08-19T00:00:00.000Z',
#   'tags': ['substrate',
#    'polkadot',
#    'binance-chain',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'coinfund-portfolio',
#    'fabric-ventures-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kinetic-capital',
#    '1confirmation-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 987579314.957085,
#   'total_supply': 1103303471.382273,
#   'platform': None,
#   'cmc_rank': 8,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 43.64981361421515,
#     'volume_24h': 3102473154.7704735,
#     'volume_change_24h': -23.3847,
#     'percent_change_1h': 3.53988546,
#     'percent_change_24h': 9.43233593,
#     'percent_change_7d': 28.87382588,
#     'percent_change_30d': 19.50487458,
#     'percent_change_60d': 77.39795003,
#     'percent_change_90d': 244.01171583,
#     'market_cap': 43107653027.13104,
#     'market_cap_dominance': 1.736,
#     'fully_diluted_market_cap': 48158990885.75,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 1649,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'stablecoin',
#    'stablecoin-asset-backed',
#    'binance-smart-chain',
#    'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 32754559243.271255,
#   'total_supply': 32754559243.271255,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'cmc_rank': 9,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 0.99958395620601,
#     'volume_24h': 3988678529.0060997,
#     'volume_change_24h': 21.5061,
#     'percent_change_1h': -0.0341086,
#     'percent_change_24h': -0.02319698,
#     'percent_change_7d': -0.04671919,
#     'percent_change_30d': -0.04445687,
#     'percent_change_60d': -0.0486891,
#     'percent_change_90d': -0.06272842,
#     'market_cap': 32740931912.173218,
#     'market_cap_dominance': 1.3185,
#     'fully_diluted_market_cap': 32740931912.17,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 386,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'memes',
#    'payments',
#    'binance-smart-chain',
#    'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 131705676457.54765,
#   'total_supply': 131705676457.54765,
#   'platform': None,
#   'cmc_rank': 10,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 0.2395598498293,
#     'volume_24h': 1731784553.9318569,
#     'volume_change_24h': 24.8967,
#     'percent_change_1h': 0.6767909,
#     'percent_change_24h': 2.17276784,
#     'percent_change_7d': -3.82405152,
#     'percent_change_30d': -2.86400183,
#     'percent_change_60d': -25.20760865,
#     'percent_change_90d': 20.43763165,
#     'market_cap': 31551392073.83649,
#     'market_cap_dominance': 1.2706,
#     'fully_diluted_market_cap': 31551392073.84,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'slug': 'uniswap',
#   'num_market_pairs': 299,
#   'date_added': '2020-09-17T00:00:00.000Z',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'governance',
#    'blockchain-capital-portfolio',
#    'defiance-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'parafi-capital',
#    'paradigm-xzy-screener'],
#   'max_supply': 1000000000,
#   'circulating_supply': 611643723.831094,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   'cmc_rank': 11,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 25.79935978379149,
#     'volume_24h': 502334787.5031659,
#     'volume_change_24h': 2.0473,
#     'percent_change_1h': -0.45195119,
#     'percent_change_24h': -1.52921946,
#     'percent_change_7d': 2.28510847,
#     'percent_change_30d': -1.50324733,
#     'percent_change_60d': -13.05355459,
#     'percent_change_90d': 56.74480109,
#     'market_cap': 15780016490.616396,
#     'market_cap_dominance': 0.6355,
#     'fully_diluted_market_cap': 25799359783.79,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 4172,
#   'name': 'Terra',
#   'symbol': 'LUNA',
#   'slug': 'terra-luna',
#   'num_market_pairs': 89,
#   'date_added': '2019-07-26T00:00:00.000Z',
#   'tags': ['cosmos-ecosystem',
#    'store-of-value',
#    'defi',
#    'payments',
#    'coinbase-ventures-portfolio',
#    'binance-labs-portfolio',
#    'solana-ecosystem',
#    'arrington-xrp-capital',
#    'hashkey-capital-portfolio',
#    'kinetic-capital',
#    'huobi-capital',
#    'pantera-capital-portfolio',
#    'terra-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 401827951.1047928,
#   'total_supply': 970999392.238069,
#   'platform': None,
#   'cmc_rank': 12,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 37.63764151304096,
#     'volume_24h': 870678558.758436,
#     'volume_change_24h': -19.8392,
#     'percent_change_1h': 0.32365198,
#     'percent_change_24h': 1.14429765,
#     'percent_change_7d': -14.15151173,
#     'percent_change_30d': 2.40265951,
#     'percent_change_60d': 66.51023471,
#     'percent_change_90d': 473.96872926,
#     'market_cap': 15123856373.601942,
#     'market_cap_dominance': 0.6091,
#     'fully_diluted_market_cap': 36546127034.44,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 3717,
#   'name': 'Wrapped Bitcoin',
#   'symbol': 'WBTC',
#   'slug': 'wrapped-bitcoin',
#   'num_market_pairs': 222,
#   'date_added': '2019-01-30T00:00:00.000Z',
#   'tags': ['medium-of-exchange', 'defi', 'wrapped-tokens', 'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 215765.43494263,
#   'total_supply': 215765.43494263,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   'cmc_rank': 13,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 61358.61071602521,
#     'volume_24h': 582870767.8477092,
#     'volume_change_24h': 25.9138,
#     'percent_change_1h': -0.35705177,
#     'percent_change_24h': 6.24083072,
#     'percent_change_7d': 12.27448725,
#     'percent_change_30d': 27.50266032,
#     'percent_change_60d': 33.09459784,
#     'percent_change_90d': 92.59786529,
#     'market_cap': 13239067328.618696,
#     'market_cap_dominance': 0.5332,
#     'fully_diluted_market_cap': 13239067328.62,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 4687,
#   'name': 'Binance USD',
#   'symbol': 'BUSD',
#   'slug': 'binance-usd',
#   'num_market_pairs': 1473,
#   'date_added': '2019-09-20T00:00:00.000Z',
#   'tags': ['stablecoin',
#    'stablecoin-asset-backed',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 13230086600.83,
#   'total_supply': 13230086600.83,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'BUSD-BD1'},
#   'cmc_rank': 14,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 0.99964289594564,
#     'volume_24h': 7379284357.608024,
#     'volume_change_24h': 25.7308,
#     'percent_change_1h': -0.02197993,
#     'percent_change_24h': -0.0199276,
#     'percent_change_7d': -0.03873646,
#     'percent_change_30d': -0.05487731,
#     'percent_change_60d': -0.03291632,
#     'percent_change_90d': -0.0443919,
#     'market_cap': 13225362083.26531,
#     'market_cap_dominance': 0.5326,
#     'fully_diluted_market_cap': 13225362083.27,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 691,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 84000000,
#   'circulating_supply': 68755995.4967574,
#   'total_supply': 84000000,
#   'platform': None,
#   'cmc_rank': 15,
#   'last_updated': '2021-10-15T20:01:02.000Z',
#   'quote': {'USD': {'price': 190.4633812267545,
#     'volume_24h': 3274457692.962798,
#     'volume_change_24h': 21.5616,
#     'percent_change_1h': 0.03290605,
#     'percent_change_24h': 5.25391787,
#     'percent_change_7d': 6.81039399,
#     'percent_change_30d': 2.93073048,
#     'percent_change_60d': 5.5913705,
#     'percent_change_90d': 55.98305385,
#     'market_cap': 13095499381.923922,
#     'market_cap_dominance': 0.5274,
#     'fully_diluted_market_cap': 15998924023.05,
#     'last_updated': '2021-10-15T20:01:02.000Z'}}},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 496,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': ['platform',
#    'defi',
#    'oracles',
#    'smart-contracts',
#    'substrate',
#    'polkadot',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'framework-ventures',
#    'polygon-ecosystem',
#    'fantom-ecosystem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 459509553.9174637,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'cmc_rank': 16,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 27.00937794779022,
#     'volume_24h': 1217661345.665932,
#     'volume_change_24h': -14.6112,
#     'percent_change_1h': -0.1103424,
#     'percent_change_24h': -0.19480323,
#     'percent_change_7d': 0.185305,
#     'percent_change_30d': -11.9696885,
#     'percent_change_60d': -5.08935922,
#     'percent_change_90d': 73.19292005,
#     'market_cap': 12411067212.377266,
#     'market_cap_dominance': 0.4998,
#     'fully_diluted_market_cap': 27009377947.79,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 5805,
#   'name': 'Avalanche',
#   'symbol': 'AVAX',
#   'slug': 'avalanche',
#   'num_market_pairs': 98,
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'tags': ['defi',
#    'smart-contracts',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'avalanche-ecosystem',
#    'cms-holdings-portfolio',
#    'dragonfly-capital-portfolio'],
#   'max_supply': 720000000,
#   'circulating_supply': 220286577.20755112,
#   'total_supply': 391128418.8675511,
#   'platform': None,
#   'cmc_rank': 17,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 56.30044574180374,
#     'volume_24h': 530589218.1466144,
#     'volume_change_24h': -5.1062,
#     'percent_change_1h': -0.21163006,
#     'percent_change_24h': 0.21079921,
#     'percent_change_7d': -9.09725253,
#     'percent_change_30d': 2.24400688,
#     'percent_change_60d': 181.81698005,
#     'percent_change_90d': 411.84481016,
#     'market_cap': 12402232487.721394,
#     'market_cap_dominance': 0.4995,
#     'fully_diluted_market_cap': 40536320934.1,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 508,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'marketplace',
#    'medium-of-exchange',
#    'store-of-value',
#    'enterprise-solutions',
#    'payments',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 21000000,
#   'circulating_supply': 18873181.25,
#   'total_supply': 18873181.25,
#   'platform': None,
#   'cmc_rank': 18,
#   'last_updated': '2021-10-15T20:00:11.000Z',
#   'quote': {'USD': {'price': 630.3883812270627,
#     'volume_24h': 1668076684.7040784,
#     'volume_change_24h': 44.1518,
#     'percent_change_1h': -0.06067381,
#     'percent_change_24h': 5.4388217,
#     'percent_change_7d': 4.44553202,
#     'percent_change_30d': -3.16248613,
#     'percent_change_60d': -7.42007086,
#     'percent_change_90d': 42.12007302,
#     'market_cap': 11897434176.792452,
#     'market_cap_dominance': 0.4791,
#     'fully_diluted_market_cap': 13238156005.77,
#     'last_updated': '2021-10-15T20:00:11.000Z'}}},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'slug': 'algorand',
#   'num_market_pairs': 153,
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'arrington-xrp-capital',
#    'kinetic-capital',
#    'usv-portfolio',
#    'multicoin-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 10000000000,
#   'circulating_supply': 6144804323.888708,
#   'total_supply': 6613025509.6846,
#   'platform': None,
#   'cmc_rank': 19,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 1.76936216065114,
#     'volume_24h': 315189383.2399868,
#     'volume_change_24h': -16.5698,
#     'percent_change_1h': -0.06787711,
#     'percent_change_24h': -1.76432455,
#     'percent_change_7d': -9.03136735,
#     'percent_change_30d': -13.44454971,
#     'percent_change_60d': 84.00715435,
#     'percent_change_90d': 121.80708816,
#     'market_cap': 10872384255.294193,
#     'market_cap_dominance': 0.4379,
#     'fully_diluted_market_cap': 17693621606.51,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 5994,
#   'name': 'SHIBA INU',
#   'symbol': 'SHIB',
#   'slug': 'shiba-inu',
#   'num_market_pairs': 197,
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'tags': ['memes', 'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 394796000000000,
#   'total_supply': 1000000000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   'cmc_rank': 20,
#   'last_updated': '2021-10-15T20:00:14.000Z',
#   'quote': {'USD': {'price': 2.664891292e-05,
#     'volume_24h': 4014876934.9706516,
#     'volume_change_24h': 45.128,
#     'percent_change_1h': 4.25339999,
#     'percent_change_24h': -3.0604279,
#     'percent_change_7d': -1.12150124,
#     'percent_change_30d': 295.2885844,
#     'percent_change_60d': 199.21833409,
#     'percent_change_90d': 283.4157954,
#     'market_cap': 10520884225.16432,
#     'market_cap_dominance': 0.4237,
#     'fully_diluted_market_cap': 26648912924.24,
#     'last_updated': '2021-10-15T20:00:14.000Z'}}},
#  {'id': 3890,
#   'name': 'Polygon',
#   'symbol': 'MATIC',
#   'slug': 'polygon',
#   'num_market_pairs': 255,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'state-channels',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'polygon-ecosystem'],
#   'max_supply': 10000000000,
#   'circulating_supply': 6720693342.9,
#   'total_supply': 10000000000,
#   'platform': None,
#   'cmc_rank': 21,
#   'last_updated': '2021-10-15T20:00:10.000Z',
#   'quote': {'USD': {'price': 1.48304084146654,
#     'volume_24h': 3997129282.91915,
#     'volume_change_24h': 541.8964,
#     'percent_change_1h': -1.00407846,
#     'percent_change_24h': 18.26332567,
#     'percent_change_7d': 7.36156729,
#     'percent_change_30d': 7.97139223,
#     'percent_change_60d': 0.86336174,
#     'percent_change_90d': 80.86618109,
#     'market_cap': 9967062710.492989,
#     'market_cap_dominance': 0.4014,
#     'fully_diluted_market_cap': 14830408414.67,
#     'last_updated': '2021-10-15T20:00:10.000Z'}}},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 366,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'decentralized-exchange',
#    'smart-contracts',
#    'hashkey-capital-portfolio'],
#   'max_supply': 50001806812,
#   'circulating_supply': 24075246581.754326,
#   'total_supply': 50001802722.242294,
#   'platform': None,
#   'cmc_rank': 22,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 0.36431970983239,
#     'volume_24h': 822785494.1823918,
#     'volume_change_24h': -10.458,
#     'percent_change_1h': -0.3562877,
#     'percent_change_24h': -0.91402156,
#     'percent_change_7d': 6.55754407,
#     'percent_change_30d': 7.88678015,
#     'percent_change_60d': -4.58816566,
#     'percent_change_90d': 53.69166011,
#     'market_cap': 8771086848.807974,
#     'market_cap_dominance': 0.3532,
#     'fully_diluted_market_cap': 18216643748.84,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'slug': 'vechain',
#   'num_market_pairs': 145,
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'tags': ['logistics',
#    'data-provenance',
#    'iot',
#    'smart-contracts',
#    'fenbushi-capital-portfolio'],
#   'max_supply': 86712634466,
#   'circulating_supply': 64315576989,
#   'total_supply': 86712634466,
#   'platform': None,
#   'cmc_rank': 23,
#   'last_updated': '2021-10-15T20:01:02.000Z',
#   'quote': {'USD': {'price': 0.12214813549755,
#     'volume_24h': 630792163.5729162,
#     'volume_change_24h': -3.5243,
#     'percent_change_1h': -0.46839692,
#     'percent_change_24h': 2.27733896,
#     'percent_change_7d': 7.91764377,
#     'percent_change_30d': 1.01034581,
#     'percent_change_60d': -6.51237597,
#     'percent_change_90d': 83.74559269,
#     'market_cap': 7856027812.655481,
#     'market_cap_dominance': 0.3164,
#     'fully_diluted_market_cap': 10591786624.1,
#     'last_updated': '2021-10-15T20:01:02.000Z'}}},
#  {'id': 6783,
#   'name': 'Axie Infinity',
#   'symbol': 'AXS',
#   'slug': 'axie-infinity',
#   'num_market_pairs': 135,
#   'date_added': '2020-08-31T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'gaming',
#    'binance-launchpad',
#    'metaverse',
#    'defiance-capital',
#    'play-to-earn'],
#   'max_supply': 270000000,
#   'circulating_supply': 60907500,
#   'total_supply': 270000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#   'cmc_rank': 24,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 128.62939735812856,
#     'volume_24h': 1561398658.4474301,
#     'volume_change_24h': 10.9343,
#     'percent_change_1h': 0.23029331,
#     'percent_change_24h': -7.53193792,
#     'percent_change_7d': 2.9101598,
#     'percent_change_30d': 88.7445438,
#     'percent_change_60d': 89.25413944,
#     'percent_change_90d': 584.7203615,
#     'market_cap': 7834495019.590215,
#     'market_cap_dominance': 0.3155,
#     'fully_diluted_market_cap': 34729937286.69,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 2280,
#   'name': 'Filecoin',
#   'symbol': 'FIL',
#   'slug': 'filecoin',
#   'num_market_pairs': 152,
#   'date_added': '2017-12-13T00:00:00.000Z',
#   'tags': ['mineable',
#    'distributed-computing',
#    'filesharing',
#    'storage',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'hashkey-capital-portfolio',
#    'a16z-portfolio',
#    'winklevoss-capital',
#    'pantera-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 113232006,
#   'total_supply': 113232006,
#   'platform': None,
#   'cmc_rank': 25,
#   'last_updated': '2021-10-15T20:01:04.000Z',
#   'quote': {'USD': {'price': 68.40202765417817,
#     'volume_24h': 1001853911.5428206,
#     'volume_change_24h': 2.7452,
#     'percent_change_1h': -0.16116298,
#     'percent_change_24h': -3.25694867,
#     'percent_change_7d': -12.94027575,
#     'percent_change_30d': -19.86739324,
#     'percent_change_60d': -6.82833448,
#     'percent_change_90d': 48.74289298,
#     'market_cap': 7745298805.750069,
#     'market_cap_dominance': 0.3119,
#     'fully_diluted_market_cap': 7745298805.75,
#     'last_updated': '2021-10-15T20:01:04.000Z'}}},
#  {'id': 8916,
#   'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'slug': 'internet-computer',
#   'num_market_pairs': 78,
#   'date_added': '2021-03-23T00:00:00.000Z',
#   'tags': ['platform',
#    'distributed-computing',
#    'polychain-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 173832532.15,
#   'total_supply': 473829032.5711919,
#   'platform': None,
#   'cmc_rank': 26,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 43.17278794752624,
#     'volume_24h': 409744172.98705924,
#     'volume_change_24h': 7.8775,
#     'percent_change_1h': -0.76722573,
#     'percent_change_24h': 0.71824068,
#     'percent_change_7d': -14.49691754,
#     'percent_change_30d': -29.77574049,
#     'percent_change_60d': -29.74492701,
#     'percent_change_90d': 30.48179463,
#     'market_cap': 7504835048.893488,
#     'market_cap_dominance': 0.3022,
#     'fully_diluted_market_cap': 20456520346.58,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 189,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': ['platform',
#    'cosmos-ecosystem',
#    'content-creation',
#    'interoperability',
#    'binance-chain',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'hashkey-capital-portfolio',
#    '1confirmation-portfolio',
#    'paradigm-xzy-screener',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 222966174.728937,
#   'total_supply': 280750777.728937,
#   'platform': None,
#   'cmc_rank': 27,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 33.56050626974734,
#     'volume_24h': 541268003.3560164,
#     'volume_change_24h': -28.9917,
#     'percent_change_1h': 0.43957399,
#     'percent_change_24h': -0.971762,
#     'percent_change_7d': -6.66349007,
#     'percent_change_30d': -1.49741361,
#     'percent_change_60d': 108.60597036,
#     'percent_change_90d': 201.54160933,
#     'market_cap': 7482857704.932072,
#     'market_cap_dominance': 0.3014,
#     'fully_diluted_market_cap': 9422138236.21,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 522,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['media', 'payments', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 71659657369.49,
#   'total_supply': 100850743811.662,
#   'platform': None,
#   'cmc_rank': 28,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 0.09978853999823,
#     'volume_24h': 1526359023.0059128,
#     'volume_change_24h': 27.3773,
#     'percent_change_1h': -0.23953749,
#     'percent_change_24h': 2.62731085,
#     'percent_change_7d': 1.46922724,
#     'percent_change_30d': -16.6885384,
#     'percent_change_60d': 10.24474506,
#     'percent_change_90d': 76.2324879,
#     'market_cap': 7150812585.67481,
#     'market_cap_dominance': 0.288,
#     'fully_diluted_market_cap': 10063748482.7,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 265,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'ethash',
#    'platform',
#    'smart-contracts',
#    'binance-smart-chain',
#    'dcg-portfolio'],
#   'max_supply': 210700000,
#   'circulating_supply': 130230484.61388573,
#   'total_supply': 210700000,
#   'platform': None,
#   'cmc_rank': 29,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 54.85506962706476,
#     'volume_24h': 1205763776.9329717,
#     'volume_change_24h': 49.9655,
#     'percent_change_1h': -0.1832784,
#     'percent_change_24h': 0.68713123,
#     'percent_change_7d': 1.40469131,
#     'percent_change_30d': -6.37355723,
#     'percent_change_60d': -22.1615119,
#     'percent_change_90d': 27.83294135,
#     'market_cap': 7143802301.061088,
#     'market_cap_dominance': 0.2877,
#     'fully_diluted_market_cap': 11557963170.42,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 4195,
#   'name': 'FTX Token',
#   'symbol': 'FTT',
#   'slug': 'ftx-token',
#   'num_market_pairs': 88,
#   'date_added': '2019-07-31T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'derivatives',
#    'cms-holdings-portfolio',
#    'kinetic-capital',
#    'alameda-research-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 352170015,
#   'circulating_supply': 120455699.41874374,
#   'total_supply': 336326035.4859715,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'FTT-F11'},
#   'cmc_rank': 30,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 57.04732025707031,
#     'volume_24h': 311074892.04801196,
#     'volume_change_24h': 5.8343,
#     'percent_change_1h': -0.63414151,
#     'percent_change_24h': 3.31946377,
#     'percent_change_7d': 1.60274331,
#     'percent_change_30d': -20.34529899,
#     'percent_change_60d': 13.41807303,
#     'percent_change_90d': 111.82142525,
#     'market_cap': 6871674861.530473,
#     'market_cap_dominance': 0.2767,
#     'fully_diluted_market_cap': 20090355630.64,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 4943,
#   'name': 'Dai',
#   'symbol': 'DAI',
#   'slug': 'multi-collateral-dai',
#   'num_market_pairs': 479,
#   'date_added': '2019-11-22T00:00:00.000Z',
#   'tags': ['defi',
#    'stablecoin',
#    'ethereum',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'polygon-ecosystem',
#    'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 6474951713.635377,
#   'total_supply': 6474952202.474523,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#   'cmc_rank': 31,
#   'last_updated': '2021-10-15T20:00:11.000Z',
#   'quote': {'USD': {'price': 1.00005734031198,
#     'volume_24h': 1160439669.5030692,
#     'volume_change_24h': 119.7035,
#     'percent_change_1h': -0.07100594,
#     'percent_change_24h': -0.03535683,
#     'percent_change_7d': -0.04376274,
#     'percent_change_30d': -0.08547463,
#     'percent_change_60d': -0.01214536,
#     'percent_change_90d': -0.10489211,
#     'market_cap': 6475322989.386692,
#     'market_cap_dominance': 0.2608,
#     'fully_diluted_market_cap': 6475323478.25,
#     'last_updated': '2021-10-15T20:00:11.000Z'}}},
#  {'id': 4023,
#   'name': 'Bitcoin BEP2',
#   'symbol': 'BTCB',
#   'slug': 'bitcoin-bep2',
#   'num_market_pairs': 54,
#   'date_added': '2019-06-18T00:00:00.000Z',
#   'tags': ['binance-chain', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 105095.88964723,
#   'total_supply': 112501,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'BTCB-1DE'},
#   'cmc_rank': 32,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 61400.57679641368,
#     'volume_24h': 76466535.15306282,
#     'volume_change_24h': -14.3484,
#     'percent_change_1h': -0.30031019,
#     'percent_change_24h': 6.17198121,
#     'percent_change_7d': 12.45531383,
#     'percent_change_30d': 27.9035176,
#     'percent_change_60d': 33.11017574,
#     'percent_change_90d': 92.9910462,
#     'market_cap': 6452948243.272163,
#     'market_cap_dominance': 0.2599,
#     'fully_diluted_market_cap': 6907626290.17,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 2416,
#   'name': 'THETA',
#   'symbol': 'THETA',
#   'slug': 'theta',
#   'num_market_pairs': 78,
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'tags': ['media',
#    'collectibles-nfts',
#    'content-creation',
#    'video',
#    'huobi-capital'],
#   'max_supply': 1000000000,
#   'circulating_supply': 1000000000,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 33,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 6.28882691222702,
#     'volume_24h': 309193042.2043385,
#     'volume_change_24h': 38.7131,
#     'percent_change_1h': -0.20389081,
#     'percent_change_24h': 3.33529467,
#     'percent_change_7d': -4.11032009,
#     'percent_change_30d': -8.51869182,
#     'percent_change_60d': -17.30012086,
#     'percent_change_90d': 40.33604637,
#     'market_cap': 6288826912.22702,
#     'market_cap_dominance': 0.2533,
#     'fully_diluted_market_cap': 6288826912.23,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 2011,
#   'name': 'Tezos',
#   'symbol': 'XTZ',
#   'slug': 'tezos',
#   'num_market_pairs': 171,
#   'date_added': '2017-10-06T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'enterprise-solutions',
#    'collectibles-nfts',
#    'defi',
#    'smart-contracts',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'boostvc-portfolio',
#    'winklevoss-capital'],
#   'max_supply': None,
#   'circulating_supply': 863284060.186413,
#   'total_supply': 892438379.286164,
#   'platform': None,
#   'cmc_rank': 34,
#   'last_updated': '2021-10-15T20:00:18.000Z',
#   'quote': {'USD': {'price': 6.95434235450823,
#     'volume_24h': 385135577.87792087,
#     'volume_change_24h': 8.3883,
#     'percent_change_1h': 0.37108525,
#     'percent_change_24h': -2.73228557,
#     'percent_change_7d': -5.86508227,
#     'percent_change_30d': -1.11638817,
#     'percent_change_60d': 86.75807622,
#     'percent_change_90d': 181.71714646,
#     'market_cap': 6003572903.726205,
#     'market_cap_dominance': 0.2418,
#     'fully_diluted_market_cap': 6206322019.86,
#     'last_updated': '2021-10-15T20:00:18.000Z'}}},
#  {'id': 4642,
#   'name': 'Hedera',
#   'symbol': 'HBAR',
#   'slug': 'hedera',
#   'num_market_pairs': 68,
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'tags': ['dag',
#    'marketplace',
#    'enterprise-solutions',
#    'payments',
#    'dcg-portfolio'],
#   'max_supply': 50000000000,
#   'circulating_supply': 14832972490.75805,
#   'total_supply': 50000000000,
#   'platform': None,
#   'cmc_rank': 35,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 0.37079739927896,
#     'volume_24h': 309600707.7961843,
#     'volume_change_24h': -16.6977,
#     'percent_change_1h': 0.68165889,
#     'percent_change_24h': -3.0110395,
#     'percent_change_7d': -2.69095556,
#     'percent_change_30d': -29.91330096,
#     'percent_change_60d': 50.21122959,
#     'percent_change_90d': 96.78042997,
#     'market_cap': 5500027623.149443,
#     'market_cap_dominance': 0.2215,
#     'fully_diluted_market_cap': 18539869963.95,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 3513,
#   'name': 'Fantom',
#   'symbol': 'FTM',
#   'slug': 'fantom',
#   'num_market_pairs': 110,
#   'date_added': '2018-10-29T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'defi',
#    'research',
#    'scaling',
#    'smart-contracts',
#    'binance-smart-chain',
#    'fantom-ecosystem'],
#   'max_supply': 3175000000,
#   'circulating_supply': 2545006273,
#   'total_supply': 2545006273,
#   'platform': None,
#   'cmc_rank': 36,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 1.96286116925327,
#     'volume_24h': 455393460.00327784,
#     'volume_change_24h': -0.8473,
#     'percent_change_1h': 0.0682351,
#     'percent_change_24h': -4.62704766,
#     'percent_change_7d': -16.52203779,
#     'percent_change_30d': 30.11561803,
#     'percent_change_60d': 389.90959595,
#     'percent_change_90d': 892.69108532,
#     'market_cap': 4995493988.777687,
#     'market_cap_dominance': 0.2012,
#     'fully_diluted_market_cap': 6232084212.38,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 328,
#   'name': 'Monero',
#   'symbol': 'XMR',
#   'slug': 'monero',
#   'num_market_pairs': 151,
#   'date_added': '2014-05-21T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'medium-of-exchange',
#    'privacy',
#    'ringct',
#    'boostvc-portfolio',
#    'electric-capital-portfolio',
#    'galaxy-digital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 18011714.67049078,
#   'total_supply': 18011714.67049078,
#   'platform': None,
#   'cmc_rank': 37,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 275.10332113933487,
#     'volume_24h': 224309489.1157551,
#     'volume_change_24h': 35.8365,
#     'percent_change_1h': -0.18606335,
#     'percent_change_24h': 2.69558326,
#     'percent_change_7d': -3.32648781,
#     'percent_change_30d': 1.854334,
#     'percent_change_60d': 0.99094238,
#     'percent_change_90d': 38.10180882,
#     'market_cap': 4955082525.266094,
#     'market_cap_dominance': 0.1996,
#     'fully_diluted_market_cap': 4955082525.27,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 3635,
#   'name': 'Crypto.com Coin',
#   'symbol': 'CRO',
#   'slug': 'crypto-com-coin',
#   'num_market_pairs': 104,
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'cosmos-ecosystem',
#    'centralized-exchange',
#    'mobile',
#    'payments'],
#   'max_supply': 30263013692,
#   'circulating_supply': 25263013692,
#   'total_supply': 30263013692,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   'cmc_rank': 38,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 0.18990877758241,
#     'volume_24h': 44914160.82349849,
#     'volume_change_24h': 20.7443,
#     'percent_change_1h': -0.55179987,
#     'percent_change_24h': 0.2412308,
#     'percent_change_7d': -2.57564554,
#     'percent_change_30d': 1.07188638,
#     'percent_change_60d': 27.18419736,
#     'percent_change_90d': 66.72207675,
#     'market_cap': 4797668048.295406,
#     'market_cap_dominance': 0.1932,
#     'fully_diluted_market_cap': 5747211936.21,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 6892,
#   'name': 'Elrond',
#   'symbol': 'EGLD',
#   'slug': 'elrond-egld',
#   'num_market_pairs': 57,
#   'date_added': '2020-09-04T00:00:00.000Z',
#   'tags': ['binance-smart-chain',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'electric-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 31415926,
#   'circulating_supply': 19592729.0966713,
#   'total_supply': 22568428,
#   'platform': None,
#   'cmc_rank': 39,
#   'last_updated': '2021-10-15T20:00:12.000Z',
#   'quote': {'USD': {'price': 238.78437219088534,
#     'volume_24h': 92817159.15493724,
#     'volume_change_24h': 7.5758,
#     'percent_change_1h': -0.39404573,
#     'percent_change_24h': -1.99539756,
#     'percent_change_7d': -9.77736159,
#     'percent_change_30d': -8.09402243,
#     'percent_change_60d': 75.89972725,
#     'percent_change_90d': 217.79535407,
#     'market_cap': 4678437516.854748,
#     'market_cap_dominance': 0.1884,
#     'fully_diluted_market_cap': 7501632166.71,
#     'last_updated': '2021-10-15T20:00:12.000Z'}}},
#  {'id': 7186,
#   'name': 'PancakeSwap',
#   'symbol': 'CAKE',
#   'slug': 'pancakeswap',
#   'num_market_pairs': 136,
#   'date_added': '2020-09-25T00:00:00.000Z',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'yield-farming',
#    'binance-chain',
#    'amm',
#    'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 232035413.1787089,
#   'total_supply': 232035413.1787089,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   'cmc_rank': 40,
#   'last_updated': '2021-10-15T20:01:02.000Z',
#   'quote': {'USD': {'price': 19.90184588110001,
#     'volume_24h': 316202026.6059502,
#     'volume_change_24h': -30.9119,
#     'percent_change_1h': 0.00574082,
#     'percent_change_24h': -0.03261369,
#     'percent_change_7d': 0.68594101,
#     'percent_change_30d': -10.99984941,
#     'percent_change_60d': -8.04579697,
#     'percent_change_90d': 55.11950075,
#     'market_cap': 4617933032.040027,
#     'market_cap_dominance': 0.186,
#     'fully_diluted_market_cap': 4617933032.04,
#     'last_updated': '2021-10-15T20:01:02.000Z'}}},
#  {'id': 1765,
#   'name': 'EOS',
#   'symbol': 'EOS',
#   'slug': 'eos',
#   'num_market_pairs': 410,
#   'date_added': '2017-07-01T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'smart-contracts',
#    'binance-chain',
#    'binance-smart-chain',
#    'fenbushi-capital-portfolio',
#    'galaxy-digital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 960758172.5946,
#   'total_supply': 1036758584.4373,
#   'platform': None,
#   'cmc_rank': 41,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 4.69999101619148,
#     'volume_24h': 1294918755.642474,
#     'volume_change_24h': 33.0742,
#     'percent_change_1h': 0.41210813,
#     'percent_change_24h': 0.77316208,
#     'percent_change_7d': 0.13001835,
#     'percent_change_30d': -7.78451003,
#     'percent_change_60d': -16.57004857,
#     'percent_change_90d': 26.25750173,
#     'market_cap': 4515554779.927163,
#     'market_cap_dominance': 0.1819,
#     'fully_diluted_market_cap': 4872756032.81,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 6535,
#   'name': 'NEAR Protocol',
#   'symbol': 'NEAR',
#   'slug': 'near-protocol',
#   'num_market_pairs': 67,
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'tags': ['platform',
#    'staking',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'coinfund-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'kinetic-capital'],
#   'max_supply': 1000000000,
#   'circulating_supply': 520055352,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 42,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 7.95166130573585,
#     'volume_24h': 247443883.99923527,
#     'volume_change_24h': 16.6979,
#     'percent_change_1h': -0.30558157,
#     'percent_change_24h': 1.17552423,
#     'percent_change_7d': -3.94231813,
#     'percent_change_30d': -13.31165918,
#     'percent_change_60d': 131.9815936,
#     'percent_change_90d': 291.69236567,
#     'market_cap': 4135304019.3392367,
#     'market_cap_dominance': 0.1665,
#     'fully_diluted_market_cap': 7951661305.74,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 4256,
#   'name': 'Klaytn',
#   'symbol': 'KLAY',
#   'slug': 'klaytn',
#   'num_market_pairs': 59,
#   'date_added': '2020-03-30T00:00:00.000Z',
#   'tags': ['platform', 'enterprise-solutions'],
#   'max_supply': None,
#   'circulating_supply': 2513262737.2,
#   'total_supply': 10696861225.6,
#   'platform': None,
#   'cmc_rank': 43,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 1.60696537484784,
#     'volume_24h': 123114903.99952582,
#     'volume_change_24h': -4.6673,
#     'percent_change_1h': 0.58668008,
#     'percent_change_24h': -1.01821834,
#     'percent_change_7d': -0.19378642,
#     'percent_change_30d': 18.34596409,
#     'percent_change_60d': -13.46929969,
#     'percent_change_90d': 77.4942095,
#     'market_cap': 4038726196.5757065,
#     'market_cap_dominance': 0.1626,
#     'fully_diluted_market_cap': 17189485609.09,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 10791,
#   'name': 'eCash',
#   'symbol': 'XEC',
#   'slug': 'ecash',
#   'num_market_pairs': 37,
#   'date_added': '2021-07-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 21000000000000,
#   'circulating_supply': 18870023423313,
#   'total_supply': 18870023423313,
#   'platform': None,
#   'cmc_rank': 44,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 0.0002109047719,
#     'volume_24h': 243191070.69399184,
#     'volume_change_24h': 86.8744,
#     'percent_change_1h': -0.22297826,
#     'percent_change_24h': -3.66236393,
#     'percent_change_7d': -5.78211549,
#     'percent_change_30d': -15.59560182,
#     'percent_change_60d': 279.31384807,
#     'percent_change_90d': 812.23825012,
#     'market_cap': 3979777985.8414855,
# ...
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 6597,
#   'name': 'Degenerator Meme',
#   'symbol': 'MEME',
#   'slug': 'degenerator-meme',
#   'num_market_pairs': 14,
#   'date_added': '2020-08-16T00:00:00.000Z',
#   'tags': ['collectibles-nfts', 'yield-farming'],
#   'max_supply': 28000,
#   'circulating_supply': 28000,
#   'total_supply': 28000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xd5525d397898e5502075ea5e830d8914f6f0affe'},
#   'cmc_rank': 985,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 403.9843877308789,
#     'volume_24h': 673173.48750613,
#     'volume_change_24h': -17.2788,
#     'percent_change_1h': 1.53742055,
#     'percent_change_24h': 3.52383957,
#     'percent_change_7d': -13.52606754,
#     'percent_change_30d': -19.33040388,
#     'percent_change_60d': -44.62194701,
#     'percent_change_90d': -17.83059149,
#     'market_cap': 11311562.85646461,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 11311562.86,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 9839,
#   'name': 'BlockBank',
#   'symbol': 'BBANK',
#   'slug': 'blockbank',
#   'num_market_pairs': 8,
#   'date_added': '2021-05-16T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 400000000,
#   'circulating_supply': 67826122.03069617,
#   'total_supply': 400000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xf4b5470523ccd314c6b9da041076e7d79e0df267'},
#   'cmc_rank': 986,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 0.16664740844956,
#     'volume_24h': 1518807.41419803,
#     'volume_change_24h': -1.8397,
#     'percent_change_1h': -2.22608843,
#     'percent_change_24h': -1.37501763,
#     'percent_change_7d': 39.01347261,
#     'percent_change_30d': -8.89761371,
#     'percent_change_60d': -40.4590429,
#     'percent_change_90d': 106.04347458,
#     'market_cap': 11303047.461599125,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 66658963.38,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 1899,
#   'name': 'YOYOW',
#   'symbol': 'YOYOW',
#   'slug': 'yoyow',
#   'num_market_pairs': 3,
#   'date_added': '2017-08-19T00:00:00.000Z',
#   'tags': ['media', 'content-creation'],
#   'max_supply': None,
#   'circulating_supply': 504769404.80919,
#   'total_supply': 1052568875.38783,
#   'platform': None,
#   'cmc_rank': 987,
#   'last_updated': '2021-10-15T20:00:15.000Z',
#   'quote': {'USD': {'price': 0.02231072137991,
#     'volume_24h': 908458.35224568,
#     'volume_change_24h': 16.2486,
#     'percent_change_1h': -4.43704421,
#     'percent_change_24h': -4.09026828,
#     'percent_change_7d': -2.54496307,
#     'percent_change_30d': -11.90152302,
#     'percent_change_60d': -16.41147394,
#     'percent_change_90d': 131.52199475,
#     'market_cap': 11261769.551800841,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 23483570.91,
#     'last_updated': '2021-10-15T20:00:15.000Z'}}},
#  {'id': 8484,
#   'name': 'Olyseum',
#   'symbol': 'OLY',
#   'slug': 'olyseum',
#   'num_market_pairs': 7,
#   'date_added': '2021-02-16T00:00:00.000Z',
#   'tags': ['events',
#    'collectibles-nfts',
#    'loyalty',
#    'entertainment',
#    'reputation',
#    'social-token'],
#   'max_supply': 5000000000,
#   'circulating_supply': 1171589649.6658509,
#   'total_supply': 5000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6595b8fd9c920c81500dca94e53cdc712513fb1f'},
#   'cmc_rank': 988,
#   'last_updated': '2021-10-15T20:01:04.000Z',
#   'quote': {'USD': {'price': 0.00959225701041,
#     'volume_24h': 104410.44838721,
#     'volume_change_24h': 199.6495,
#     'percent_change_1h': 3.40395685,
#     'percent_change_24h': 4.02994629,
#     'percent_change_7d': -7.07170946,
#     'percent_change_30d': -36.75279125,
#     'percent_change_60d': -36.75035608,
#     'percent_change_90d': -38.70278214,
#     'market_cap': 11238189.030331055,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 47961285.05,
#     'last_updated': '2021-10-15T20:01:04.000Z'}}},
#  {'id': 10408,
#   'name': 'Formation Fi',
#   'symbol': 'FORM',
#   'slug': 'formation-fi',
#   'num_market_pairs': 14,
#   'date_added': '2021-06-11T00:00:00.000Z',
#   'tags': ['binance-smart-chain'],
#   'max_supply': 1000000000,
#   'circulating_supply': 79753014.899008,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x21381e026ad6d8266244f2a583b35f9e4413fa2a'},
#   'cmc_rank': 989,
#   'last_updated': '2021-10-15T20:01:04.000Z',
#   'quote': {'USD': {'price': 0.14013710789227,
#     'volume_24h': 1048129.08019387,
#     'volume_change_24h': -1.1847,
#     'percent_change_1h': -0.36907472,
#     'percent_change_24h': -6.44622753,
#     'percent_change_7d': -3.11899995,
#     'percent_change_30d': -39.43316138,
#     'percent_change_60d': -40.30277391,
#     'percent_change_90d': -33.41832558,
#     'market_cap': 11176356.8536361,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 140137107.89,
#     'last_updated': '2021-10-15T20:01:04.000Z'}}},
#  {'id': 9504,
#   'name': 'NAOS Finance',
#   'symbol': 'NAOS',
#   'slug': 'naos-finance',
#   'num_market_pairs': 14,
#   'date_added': '2021-04-30T00:00:00.000Z',
#   'tags': ['coinbase-ventures-portfolio'],
#   'max_supply': 300000000,
#   'circulating_supply': 8804863,
#   'total_supply': 210000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4a615bb7166210cce20e6642a6f8fb5d4d044496'},
#   'cmc_rank': 990,
#   'last_updated': '2021-10-15T20:01:04.000Z',
#   'quote': {'USD': {'price': 1.26724579083006,
#     'volume_24h': 2369788.91698914,
#     'volume_change_24h': 14.5218,
#     'percent_change_1h': -0.8964192,
#     'percent_change_24h': -5.2852551,
#     'percent_change_7d': -9.89308747,
#     'percent_change_30d': -2.7092246,
#     'percent_change_60d': 21.05386663,
#     'percent_change_90d': 232.09923944,
#     'market_cap': 11157925.575585335,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 380173737.25,
#     'last_updated': '2021-10-15T20:01:04.000Z'}}},
#  {'id': 7509,
#   'name': 'BoringDAO',
#   'symbol': 'BOR',
#   'slug': 'boringdao',
#   'num_market_pairs': 5,
#   'date_added': '2020-10-26T00:00:00.000Z',
#   'tags': ['defi', 'polygon-ecosystem'],
#   'max_supply': 200000,
#   'circulating_supply': 110777.02986629,
#   'total_supply': 200000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x3c9d6c1c73b31c837832c72e04d3152f051fc1a9'},
#   'cmc_rank': 991,
#   'last_updated': '2021-10-15T20:01:05.000Z',
#   'quote': {'USD': {'price': 101.01526195112385,
#     'volume_24h': 1059.46416522,
#     'volume_change_24h': 609.3967,
#     'percent_change_1h': -0.70495181,
#     'percent_change_24h': -24.30901861,
#     'percent_change_7d': 1.36065346,
#     'percent_change_30d': -48.6998942,
#     'percent_change_60d': -66.89685614,
#     'percent_change_90d': -33.30129673,
#     'market_cap': 11190170.690110754,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 20203052.39,
#     'last_updated': '2021-10-15T20:01:05.000Z'}}},
#  {'id': 77,
#   'name': 'Diamond',
#   'symbol': 'DMD',
#   'slug': 'diamond',
#   'num_market_pairs': 6,
#   'date_added': '2013-12-19T00:00:00.000Z',
#   'tags': ['masternodes', 'staking'],
#   'max_supply': 4380000,
#   'circulating_supply': 3636241.56362395,
#   'total_supply': 3636241.56362395,
#   'platform': None,
#   'cmc_rank': 992,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 3.05864815841032,
#     'volume_24h': 40603.87749551,
#     'volume_change_24h': 542.9029,
#     'percent_change_1h': 0.48812015,
#     'percent_change_24h': 6.6353695,
#     'percent_change_7d': 3.41197002,
#     'percent_change_30d': 4.33281266,
#     'percent_change_60d': 4.44585153,
#     'percent_change_90d': 53.50287425,
#     'market_cap': 11121983.562113456,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 13396878.93,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 5919,
#   'name': 'Meter Governance',
#   'symbol': 'MTRG',
#   'slug': 'meter-governance',
#   'num_market_pairs': 3,
#   'date_added': '2020-07-27T00:00:00.000Z',
#   'tags': ['defi', 'interoperability', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 2318338,
#   'total_supply': 40000000,
#   'platform': None,
#   'cmc_rank': 993,
#   'last_updated': '2021-10-15T20:00:08.000Z',
#   'quote': {'USD': {'price': 4.7850511291767,
#     'volume_24h': 85180.76607277,
#     'volume_change_24h': -9.1578,
#     'percent_change_1h': -0.09701819,
#     'percent_change_24h': -2.45336294,
#     'percent_change_7d': -5.44742245,
#     'percent_change_30d': 29.81570203,
#     'percent_change_60d': 96.83623344,
#     'percent_change_90d': 129.28169087,
#     'market_cap': 11093365.864713252,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 191402045.17,
#     'last_updated': '2021-10-15T20:00:08.000Z'}}},
#  {'id': 6870,
#   'name': 'OIN Finance',
#   'symbol': 'OIN',
#   'slug': 'oin-finance',
#   'num_market_pairs': 7,
#   'date_added': '2020-09-03T00:00:00.000Z',
#   'tags': ['avalanche-ecosystem',
#    'exnetwork-capital-portfolio',
#    'polygon-ecosystem'],
#   'max_supply': 100000000,
#   'circulating_supply': 32950759.25693466,
#   'total_supply': 100000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x9aeB50f542050172359A0e1a25a9933Bc8c01259'},
#   'cmc_rank': 994,
#   'last_updated': '2021-10-15T20:01:07.000Z',
#   'quote': {'USD': {'price': 0.33489995639733,
#     'volume_24h': 429280.83208103,
#     'volume_change_24h': -12.3273,
#     'percent_change_1h': 0.26971807,
#     'percent_change_24h': -7.04989952,
#     'percent_change_7d': -6.26881269,
#     'percent_change_30d': 19.86782264,
#     'percent_change_60d': 120.1026119,
#     'percent_change_90d': 165.83346307,
#     'market_cap': 11035207.838406336,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 33489995.64,
#     'last_updated': '2021-10-15T20:01:07.000Z'}}},
#  {'id': 11865,
#   'name': 'Bone ShibaSwap',
#   'symbol': 'BONE',
#   'slug': 'bone-shibaswap',
#   'num_market_pairs': 16,
#   'date_added': '2021-09-13T19:17:01.000Z',
#   'tags': [],
#   'max_supply': 250000000,
#   'circulating_supply': 6975299.51529947,
#   'total_supply': 158797646.31186867,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x9813037ee2218799597d83D4a5B6F3b6778218d9'},
#   'cmc_rank': 995,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 1.57671306395716,
#     'volume_24h': 3125833.15200487,
#     'volume_change_24h': 34.1992,
#     'percent_change_1h': -0.59222165,
#     'percent_change_24h': -15.53999927,
#     'percent_change_7d': -35.13415809,
#     'percent_change_30d': 54.41902483,
#     'percent_change_60d': 0,
#     'percent_change_90d': 0,
#     'market_cap': 10998045.87078672,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 394178265.99,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 53,
#   'name': 'Quark',
#   'symbol': 'QRK',
#   'slug': 'quark',
#   'num_market_pairs': 3,
#   'date_added': '2013-08-25T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'multiple-algorithms'],
#   'max_supply': None,
#   'circulating_supply': 275184630.5269182,
#   'total_supply': 275184630.5269182,
#   'platform': None,
#   'cmc_rank': 996,
#   'last_updated': '2021-10-15T20:01:03.000Z',
#   'quote': {'USD': {'price': 0.03996588509961,
#     'volume_24h': 1894.64841112,
#     'volume_change_24h': 14.5658,
#     'percent_change_1h': -0.38713843,
#     'percent_change_24h': 8.01649293,
#     'percent_change_7d': 19.86385204,
#     'percent_change_30d': 27.81508401,
#     'percent_change_60d': 80.64450298,
#     'percent_change_90d': 178.88482444,
#     'market_cap': 10997997.324817441,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 10997997.32,
#     'last_updated': '2021-10-15T20:01:03.000Z'}}},
#  {'id': 2019,
#   'name': 'Viberate',
#   'symbol': 'VIB',
#   'slug': 'viberate',
#   'num_market_pairs': 11,
#   'date_added': '2017-10-06T00:00:00.000Z',
#   'tags': ['media', 'music'],
#   'max_supply': None,
#   'circulating_supply': 196825000,
#   'total_supply': 200000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2c974b2d0ba1716e644c1fc59982a89ddd2ff724'},
#   'cmc_rank': 997,
#   'last_updated': '2021-10-15T20:00:16.000Z',
#   'quote': {'USD': {'price': 0.05568597566544,
#     'volume_24h': 1525968.84122247,
#     'volume_change_24h': 38.7035,
#     'percent_change_1h': 0.46715869,
#     'percent_change_24h': 1.65705633,
#     'percent_change_7d': 8.2323338,
#     'percent_change_30d': 11.34335872,
#     'percent_change_60d': 2.1929444,
#     'percent_change_90d': 89.80361623,
#     'market_cap': 10960392.160350228,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 11137195.13,
#     'last_updated': '2021-10-15T20:00:16.000Z'}}},
#  {'id': 2548,
#   'name': 'POA',
#   'symbol': 'POA',
#   'slug': 'poa',
#   'num_market_pairs': 7,
#   'date_added': '2018-02-28T00:00:00.000Z',
#   'tags': ['platform'],
#   'max_supply': None,
#   'circulating_supply': 292551041.46394503,
#   'total_supply': 292551041.46394503,
#   'platform': None,
#   'cmc_rank': 998,
#   'last_updated': '2021-10-15T20:01:06.000Z',
#   'quote': {'USD': {'price': 0.03684452989947,
#     'volume_24h': 1413456.46603105,
#     'volume_change_24h': 727.4735,
#     'percent_change_1h': -2.00129395,
#     'percent_change_24h': 1.10427197,
#     'percent_change_7d': 6.94354076,
#     'percent_change_30d': 2.1207264,
#     'percent_change_60d': -14.96060748,
#     'percent_change_90d': 48.32896771,
#     'market_cap': 10778905.59433941,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 10778905.59,
#     'last_updated': '2021-10-15T20:01:06.000Z'}}},
#  {'id': 5079,
#   'name': 'apM Coin',
#   'symbol': 'APM',
#   'slug': 'apm-coin',
#   'num_market_pairs': 7,
#   'date_added': '2019-12-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 361875000,
#   'total_supply': 1812500000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc8c424b91d8ce0137bab4b832b7f7d154156ba6c'},
#   'cmc_rank': 999,
#   'last_updated': '2021-10-15T20:00:17.000Z',
#   'quote': {'USD': {'price': 0.03022419115165,
#     'volume_24h': 1202908.69823339,
#     'volume_change_24h': 1480.5897,
#     'percent_change_1h': -1.25084159,
#     'percent_change_24h': -4.62051618,
#     'percent_change_7d': -3.7773998,
#     'percent_change_30d': -9.11999739,
#     'percent_change_60d': -15.34015193,
#     'percent_change_90d': 13.8247645,
#     'market_cap': 10937379.173003344,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 54781346.46,
#     'last_updated': '2021-10-15T20:00:17.000Z'}}},
#  {'id': 5963,
#   'name': 'Centric Swap',
#   'symbol': 'CNS',
#   'slug': 'centric-swap',
#   'num_market_pairs': 11,
#   'date_added': '2020-07-30T00:00:00.000Z',
#   'tags': ['services',
#    'collectibles-nfts',
#    'defi',
#    'yield-farming',
#    'binance-smart-chain',
#    'governance'],
#   'max_supply': None,
#   'circulating_supply': 7342691560,
#   'total_supply': 159158246060,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0xF6Cb4ad242BaB681EfFc5dE40f7c8FF921a12d63'},
#   'cmc_rank': 1000,
#   'last_updated': '2021-10-15T20:00:15.000Z',
#   'quote': {'USD': {'price': 0.00148619407274,
#     'volume_24h': 13777090.29514159,
#     'volume_change_24h': 104.4562,
#     'percent_change_1h': 12.77258853,
#     'percent_change_24h': 46.3557444,
#     'percent_change_7d': 464.72349867,
#     'percent_change_30d': 707.65513183,
#     'percent_change_60d': 601.03944683,
#     'percent_change_90d': 372.54425446,
#     'market_cap': 10912664.674430024,
#     'market_cap_dominance': 0.0004,
#     'fully_diluted_market_cap': 236540041.92,
#     'last_updated': '2021-10-15T20:00:15.000Z'}}},
#  ...]

# %%
for crypto in data['data']:
    if crypto['symbol'] == 'BTC':
        price = crypto['quote']['USD']['price']
        break

# %%
if price < 65000:
    print('sell')
# Out:
# sell
